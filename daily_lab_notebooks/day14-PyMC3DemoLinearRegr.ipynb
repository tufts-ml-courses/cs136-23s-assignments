# %% [markdown]
# # day 14 of CS 136 - Probabilistic Programming
#
# # Demo: Hello world for linear regression in PyMC3
#
# This is meant to be a first notebook for exploring how to use PyMC3 to do:
#
# * Part 1: MAP estimation
# * Part 2: Metropolis random walk MCMC
# * Part 3: MCMC sampling using the No-U-Turn (NUTS) extension of Hamlitonian Monte Carlo
#
# Meant to allow side-by-side comparison with Stan in the parallel second demo notebook
#
# Inspired by:
#
# * Bob Carpenter's blog post:
#
# https://statmodeling.stat.columbia.edu/2017/05/31/compare-stan-pymc3-edward-hello-world/
#
# * The "hello world" example in the PyMC3 journal article:
#
# Salvatier, Wiecki, and Fonnesbeck. "Probabilistic programming in Python using PyMC3".
# https://peerj.com/articles/cs-55.pdf

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid');
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.0})

# %matplotlib inline

# %% [markdown]
# # Import PyMC3
#
#
# If you need to install it first, using the `spr_2021s_env` conda environment just do:
#
# ```console
# $ conda activate spr_2021s_env
# $ conda install -c conda-forge pymc3
# ```

# %%
import pymc3

# %%
import arviz as az

# %% [markdown]
# # Model as MATH

# %% [markdown]
# We wish to consider a simple linear regression model.
#
# Each individual example (indexed by $n$) has an output real value $y_n$. We model each observation as (conditionally) iid using a regression given two input features/covariates $x_{n1}$ and $x_{n2}$.
#
# ### Likelihood
#
# \begin{align}
#  p(y_{1:N} | x_{1:N}, \alpha, \beta, \sigma) &= \prod_{n=1}^N \text{NormPDF}(y_n | \alpha + \beta_1 x_{n1} + \beta_2 x_{n2}, \sigma^2)
# \end{align}
#
# We can identify the 3 scalar parameters that define our mean prediction: intercept $\alpha$, and weights $\beta_1$ and $\beta_2.
#
# There is further the variance parameter $\sigma^2$.
#
# ### Priors on the variance of the likelihood:
#
# \begin{align}
#  p(\sigma) &= \text{HalfNormalPDF}(\sigma | 0, 1) =
#  \begin{cases}
#      2 \cdot \text{NormalPDF}(\sigma | 0, 1) & \sigma > 0
# \\
#      0.0  & \sigma \leq 0
#  \end{cases}
# \end{align}
#
# It is sometimes tough to find the right distribution to express our beliefs about the variance, which needs to be positive ($\sigma^2 > 0$). Here, we use the ``half-normal'' distribution, which is basically the half of the standard normal PDF that covers positive values, renormalized to be a valid pdf.
#
# ### Priors on regression coefficients:
# \begin{align}
#  p(\alpha) &= \text{NormalPDF}(0, 10)
# \\
#  p(\beta_1) &= \text{NormalPDF}(0, 10)
# \\
#  p(\beta_2) &= \text{NormalPDF}(0, 10)
# \\
# \end{align}

# %% [markdown]
# # Simulate data from the model

# %%
# Initialize random number generator
np.random.seed(123)

# True regression coefficients
alpha = 1.0
beta = np.asarray([1.0, 1.337])

# True regression std dev
sigma = 0.3

# Size of dataset
N = 100

# Data Features (input variable)
x1_N = np.random.randn(N)
x2_N = np.random.randn(N)
x_N2 = np.hstack([x1_N[:,np.newaxis], x2_N[:,np.newaxis]])

# Simulate outcome variable
y_N = alpha + beta[0]*x1_N + beta[1]*x2_N + np.random.randn(N) * sigma

true_params = dict(
    alpha=alpha,
    beta=beta,
    sigma=sigma)

# %% [markdown]
# # Plot of observed data

# %%
_, axgrid = plt.subplots(nrows=1, ncols=2, figsize=(8,3), sharex=True, sharey=True);

axgrid[0].plot(x1_N, y_N, 'k.'); axgrid[0].set_xlabel('x1'); axgrid[0].set_ylabel('y');
axgrid[1].plot(x2_N, y_N, 'b.'); axgrid[1].set_xlabel('x2'); axgrid[1].set_ylabel('y');

# %% [markdown]
# # Model specified as a PyMC3 object

# %% [markdown]
# For the N=10 smaller dataset

# %%
my_model_N10 = pymc3.Model()

with my_model_N10:
    # Priors for unknown model parameters
    alpha = pymc3.Normal('alpha', mu=0, sd=10)
    beta = pymc3.Normal('beta', mu=0, sd=10, shape=2)
    sigma = pymc3.HalfNormal('sigma', sd=1)
    
    # Likelihood (sampling distribution) of observations
    Y_obs = pymc3.Normal('Y_obs',
        mu=(alpha + beta[0] * x1_N[:10] + beta[1] * x2_N[:10]),
        sd=sigma,
        observed=y_N[:10])

# %% [markdown]
# For the N=100 bigger dataset

# %%
my_model_N100 = pymc3.Model()

with my_model_N100:
    # Priors for unknown model parameters
    alpha = pymc3.Normal('alpha', mu=0, sd=10)
    beta = pymc3.Normal('beta', mu=0, sd=10, shape=2)
    sigma = pymc3.HalfNormal('sigma', sd=1)
    
    # Likelihood (sampling distribution) of observations
    Y_obs = pymc3.Normal('Y_obs',
        mu=(alpha + beta[0] * x1_N + beta[1] * x2_N),
        sd=sigma,
        observed=y_N)

# %%
print(my_model_N100.basic_RVs)
# Out:
# [alpha, beta, sigma_log__, Y_obs]

# %% [markdown]
# # Setup: Prepare for plotting results
#
# Here's complete code for digging into the results of a PyMC sampling run and visualizing them.
#
# Can just skip over this at first, but useful to know what's going on "under the hood"

# %%
def plot_traces(fit):
    fig, ax_grid = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True);
    for ax, var_name, dim in zip(
            ax_grid.flatten(), ['alpha', 'sigma', 'beta', 'beta'], [None, None, 0, 1]):
        var_samples_S = fit[var_name]
        true_val = true_params[var_name]

        if dim is not None:
            var_samples_S = var_samples_S[:, dim]
            true_val = true_val[dim]
            var_name = var_name + "[%d]" % dim

        S = var_samples_S.size
        ax.plot(var_samples_S, 'b.', markersize=4, alpha=0.3, label='samples')
        ax.plot(true_val * np.ones(S), 'r-', label='true_value')
        ax.set_ylabel(var_name)

    ax.legend(bbox_to_anchor=(1.1, 1.0))
    ax.set_ylim([0, 2.0]);

# %% [markdown]
# # Part 1: MAP estimation
#
# ## Demo 1(i): Run MAP on N=10 dataset

# %%
map_N10 = pymc3.find_MAP(model=my_model_N10, maxeval=1000, method='L-BFGS-B')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='27' class='' max='27' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [27/27 00:00<00:00 logp = -8.0697, ||grad|| = 0.71175]
#     </div>

# %%
for key, arr in map_N10.items():
    print(key, arr)
# Out:
# alpha 1.069344037625922
# beta [1.00373515 1.44519906]
# sigma_log__ -1.607230117606145
# sigma 0.2004420467603088

# %% [markdown]
# ## Discussion 1a: Why are there both "sigma" and "sigma_log__" here?
#
# Hint: The procedure must be doing second-order gradient descent under the hood (L-BFGS)... can we use gradient descent (of any order) on parameters like $\sigma$ that must remain positive at all times?

# %% [markdown]
# ```
# TODO discuss
# ```

# %% [markdown]
# ## Demo 1(ii): Run MAP on larger N=100 dataset

# %%
map_N100 = pymc3.find_MAP(model=my_model_N100, maxeval=1000, method='L-BFGS-B')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00 logp = -28.138, ||grad|| = 0.0017975]
#     </div>

# %% [markdown]
# #### Result of MAP estimation at N=100

# %%
for key, arr in map_N100.items():
    print(key, arr)
# Out:
# alpha 0.9720043305924299
# beta [0.98456717 1.34380165]
# sigma_log__ -1.237493384514688
# sigma 0.290110502779077

# %% [markdown]
# #### Compare to true parameters

# %%
for key, arr in true_params.items():
    print(key, arr)
# Out:
# alpha 1.0
# beta [1.    1.337]
# sigma 0.3

# %% [markdown]
# ## Discussion 1b: Did the N=100 MAP estimate get closer to true parameter values than N=10?

# %% [markdown]
# ```
# TODO discuss
# ```

# %% [markdown]
# ## Part 2: Run Metropolis Random Walk MCMC sampler
#
# We'll do this on the N=10 dataset for simplicity.
#
# Remember that `S` in pyMC3 sets the std dev of the proposal for each variable in the steps below

# %%
with my_model_N10:
    start = map_N10
    
    # instantiate sampler
    rw_step1 = pymc3.Metropolis(vars=[my_model_N10.alpha], S=1.0 * np.ones(1))
    rw_step2 = pymc3.Metropolis(vars=[my_model_N10.sigma], S=0.00001 * np.ones(1))
    rw_step3 = pymc3.Metropolis(vars=[my_model_N10.beta], S=0.00001 * np.ones(2))
    
    # draw 1000 posterior samples
    rw_trace = pymc3.sample(
        1000, [rw_step1, rw_step2, rw_step3], start=start, chains=1, tune=0, discard_tuned_samples=True)
# Out:
# Sequential sampling (1 chains in 1 job)
# CompoundStep
# >Metropolis: [alpha]
# >Metropolis: [sigma]
# >Metropolis: [beta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:00<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 0 tune and 1_000 draw iterations (0 + 1_000 draws total) took 0 seconds.
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/arviz/data/base.py:169: UserWarning: More chains (1000) than draws (3). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %% [markdown]
# ### Visualize sampled values over time

# %%
plot_traces(rw_trace)

# %% [markdown]
# ### Visualize histograms and sample traces, using "arviz" library

# %%
with my_model_N10:
    az.plot_trace(rw_trace);
# Out:
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/arviz/data/base.py:169: UserWarning: More chains (1000) than draws (3). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(

# %% [markdown]
# ## Exercise 2a: Adjust the random walk standard deviation ('S') to get better samples
#
# * How would you set the proposal distribution's hyperparameter to get better results?

# %% [markdown]
# TODO experiment with code above, find a setting that works

# %% [markdown]
# # Part 3: No-U-Turn Sampler
#
# We'll now try with a more modern sampler, the No-U-Turn (NUTS) sampler

# %%
with my_model_N10:
    start = map_N10
    
    # instantiate sampler
    mcmc_step = pymc3.NUTS(scaling=start)
    
    # draw 1000 posterior samples, with initial state set to MAP estimate
    # we'll allow automatic 'tuning' of the hyperparameters
    trace = pymc3.sample(
        1000, mcmc_step, start=start, chains=1, tune=500, discard_tuned_samples=True)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /Users/mhughes/.theano/compiledir_macOS-10.16-x86_64-i386-64bit-i386-3.9.2-64/lock_dir/lock
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 500 tune and 1_000 draw iterations (500 + 1_000 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
plot_traces(trace)

# %%
with my_model_N10:
    az.plot_trace(trace);

# %% [markdown]
# # Run MCMC sampler for N=100 dataset
#
# Repeat the above with larger N=100 dataset.... how do posterior distributions change?

# %%
with my_model_N100:
    start = map_N10
    
    # instantiate sampler
    mcmc_step = pymc3.NUTS(scaling=start)
    
    # draw 1000 posterior samples
    trace_N100 = pymc3.sample(
        1000, mcmc_step, start=start, chains=1, tune=500, discard_tuned_samples=True)
# Out:
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# /Users/mhughes/miniconda3/envs/spr_2021s_env/lib/python3.9/site-packages/theano/scan_module/scan_perform_ext.py:75: UserWarning: The file scan_perform.c is not available. This donot happen normally. You are probably in a strangesetup. This mean Theano can not use the cython code for scan. If youwant to remove this warning, use the Theano flag'cxx=' (set to an empty string) to disable all ccode generation.
#   warnings.warn(
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, beta, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:00<00:00 Sampling chain 0, 0 divergences]
#     </div>
# Sampling 1 chain for 500 tune and 1_000 draw iterations (500 + 1_000 draws total) took 1 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
plot_traces(trace_N100)

# %%
with my_model_N100:
    az.plot_trace(trace_N100);

# %% [markdown]
# ## Exercise 3a: Compare N=100 to N=10 posteriors
#
# * Are the mean values different?
# * Are the variances different?
